# %%
# !pip install transformers
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline

# Load pre-trained tokenizer and model for question-answering
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")
model = AutoModelForQuestionAnswering.from_pretrained("distilbert-base-cased-distilled-squad")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# ...

# %%
# Define context and question
context = '''Mohandas Karamchand Gandhi was an Indian independence activist
who was also the leader of the Indian National Congress.
He is also known as Mahatma Gandhi or 'Bapu'.Sai Satish is gandhi best friend, Nithin is a good programmer'''

question = "What is Mahatma Gandhi known for?"
question1 = "What is other name for Mahatma Gandhi"
question2 = "Who is a good programmer?"


# Use pipeline to generate answer
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
result = nlp(question=question, context=context)

# Print answer
print(result["answer"])


result = nlp(question=question1, context=context)

# Print answer
print(result["answer"])
result = nlp(question=question2, context=context)

# Print answer
print(result["answer"])
# Out:
# Indian independence activist
# Bapu
# Nithin

# %%
# Define context and question
context = '''In the bustling city of Metropolis, Nithin, a brilliant software engineer, discovers a groundbreaking algorithm that could revolutionize the tech industry. Little does he know that his seemingly loyal friend, Dhavan, is secretly working for the villainous side, harboring ambitions of power and wealth.

As Nithin unveils his innovation to the world, Dhavan betrays him, stealing the algorithm and handing it over to the cunning villain, who goes by the name "Silhouette." Silhouette, a former colleague of Nithin, uses the algorithm for malicious purposes, endangering the privacy and security of millions.

Nithin, devastated by the betrayal of his friend and the havoc caused by his own creation, decides to take matters into his own hands. Fueled by a sense of responsibility, he transforms into an unlikely hero, determined to stop Silhouette and retrieve the algorithm.

Teaming up with his own creation, an advanced AI named "Spectra," Nithin navigates the digital and physical realms to expose Silhouette's nefarious plans. Along the way, he uncovers the villain's tragic past, realizing that Silhouette was once an idealistic coder like himself, driven to darkness by personal losses.

As Nithin faces both digital and real-world challenges, he grapples with the blurred lines between hero and villain. The story delves into the complexities of friendship, betrayal, and the consequences of unchecked technological advancements.

In a climactic confrontation, Nithin confronts Silhouette, forcing him to confront the shadows of his own creation. The battle transcends the virtual realm, testing the limits of Nithin's newfound abilities and challenging Silhouette's twisted sense of justice.

In the end, Nithin must make a choice between vengeance and redemption. "Shattered Reflections" explores the thin line that separates a hero from a villain, leaving audiences questioning the impact of their own choices in the ever-evolving digital landscape.

'''

question = "Who is Nithin"
question1 = "Who Betrayed Nithin"
question2 = "what is spectra"


# Use pipeline to generate answer
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
result = nlp(question=question, context=context)

# Print answer
print(result["answer"])


result = nlp(question=question1, context=context)

# Print answer
print(result["answer"])
result = nlp(question=question2, context=context)

# Print answer
print(result["answer"])
# Out:
# a brilliant software engineer
# Dhavan
# an advanced AI
